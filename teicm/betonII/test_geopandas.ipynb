# %%
import geopandas
import mapclassify
import matplotlib.pyplot as plt

# %%
serres_ot = geopandas.read_file(r'E:\tests\SHAPEFILES\Oikodomiki_grammi.shp')

# %%
serres_ot
# Out:
#      OBJECTID  EntID  Shape_Leng  Ï_Ð_  Shape_Le_1  \
# 0           1      1   68.083523  None   68.083523
# 1           2      2  345.327556  None  345.327556
# 2           3      3  178.753365  None  178.725998
# 3           4      4  170.901682   107  170.901682
# 4           5      7  384.352055  None  384.352055
# ..        ...    ...         ...   ...         ...
# 928       929    934  410.341041  None  410.341041
# 929       930    935  118.743783  None  118.743783
# 930       931    936    0.115783  None    0.115783
# 931       932    937  210.839055  None  210.839055
# 932       933      0    0.000000  None    0.000000
#
#                                               geometry
# 0    LINESTRING Z (462814.933 4549196.041 -0.000, 4...
# 1    LINESTRING Z (461636.952 4548746.226 -0.000, 4...
# 2    LINESTRING Z (462309.908 4549078.270 -0.000, 4...
# 3    LINESTRING Z (461208.159 4548573.278 -0.000, 4...
# 4    LINESTRING Z (461174.281 4548133.247 -0.000, 4...
# ...

# %%
serres_ot.plot(figsize=(16, 10))
plt.show()

# %%
ax = serres_ot.plot(column='Shape_Leng', scheme='QUANTILES', k=6, \
             cmap='BuPu', legend=True,
             legend_kwds={'loc': 'center left', 'bbox_to_anchor':(1,0.5)}, figsize=(16, 10))
